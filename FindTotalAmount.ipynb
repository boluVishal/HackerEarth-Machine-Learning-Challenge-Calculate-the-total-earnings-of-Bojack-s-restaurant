# %%
#1st implementaion
import os
import re 
import json
entries = os.listdir('./Extracted test')
lof = []

from nltk.corpus import stopwords
for entry in entries:
    lof.append(entry)
li=[]
def check(s):
    di=''
    for i in s:
        if(i.isdigit() or i=='.'):
            di+=i
    #print(len(di))
    if(len(di)>1):
        return float(di)
    else:
        return 0
for j in lof:
    with open(r'./Extracted text/'+j, 'r',encoding="utf-8") as f:
        l=[]
        for line in f:
            data=line.split()
            if(len(data)!=0):
                l.append(data)
        li.append(l)
        
for p in range(70):
    i=li[p]
    
    m=[]
    for j in i:
            for k in j:
                if(k.count('.')==1):
                    m.append(check(k))
    print(max(m))
# Out:
# 47.09
# 40.0
# 61.8
# 173.46
# 21.73
# 146.73
# 13.13
# 20.0
# 25.94
# 617.0
# 25.47
# 88.62
# 83.44
# 84.78
# 81.0
# 65.14
# 13.26
# 13.0
# 13.07
# 5.29
# 80.45
# 202.0
# 62.7
# 313.49
# 73.24
# 129.75
# 14.85
# 9.7
# 780.45
# 10.0
# 33.34
# 53.23
# 333.72
# 41.32
# 22.7
# 117.0
# 42.16
# 33.75
# 8.0
# 46.39
# 109.28
# 523.0
# 17.75
# 16.56
# 55.38
# 10.0
# 41.45
# 47.9
# 11.91
# 54.2
# 13.95
# 439.86
# 50.8
# 10.0
# 193.35
# 28.4
# 52.47
# 50.38
# 26.96
# 27.08
# 154.0
# 29.98
# 37.29
# 19.98
# 65.1
# 33.75
# 71128.1
# 34.0
# 154.78
# 128.33

# %%
#2nd Implementation 
import os
import re 
import json
entries = os.listdir('./Extracted test')
lof = []

from nltk.corpus import stopwords
for entry in entries:
    lof.append(entry)
li=[]
#to return the floating amount
def check(s):
    di=''
    for i in s:
        if(i.isdigit() or i=='.'):
            di+=i
    #print(len(di))
    if(len(di)>1):
        return float(di)
    else:
        return 0
for j in lof:
    with open(r'./Extracted text/'+j, 'r',encoding="utf-8") as f:
        l=[]
        for line in f:
            data=line.split()
            if(len(data)!=0):
                l.append(data)
        li.append(l)
count=0
#to find the total amount
def rsum(li):
    s=0
    n=len(li)
    best=li[0]
    for i in range(n):
        s=0.0
        for j in range(i,n):
            
            s+=li[j]
            s=round(s,2)
            #print(s,end=" ")
            if(s in li[i+1:]):
                best=max(s,best)
        #print()
    print(round(best,2))
        
for p in range(70):
    i=li[p]
    
    m=[]
    for j in i:
            for k in j:
                if(k.count('.')==1):
                    m.append(check(k))
    #print(m)
    rsum(m)
# Out:
# 47.09
# 28.31
# 61.8
# 166.74
# 21.73
# 146.73
# 13.13
# 14.17
# 25.94
# 617.0
# 25.47
# 88.62
# 83.44
# 84.78
# 46.4
# 65.14
# 13.26
# 13.0
# 13.07
# 5.29
# 80.45
# 11.69
# 62.7
# 313.49
# 73.24
# 129.75
# 14.85
# 9.7
# 780.45
# 6.59
# 33.34
# 53.23
# 333.72
# 41.32
# 22.7
# 117.0
# 42.16
# 33.75
# 7.61
# 24.99
# 109.28
# 60.0
# 17.75
# 16.56
# 55.38
# 7.56
# 41.45
# 47.9
# 11.91
# 49.5
# 12.03
# 439.86
# 50.8
# 10.0
# 193.35
# 28.4
# 52.47
# 50.38
# 24.95
# 25.3
# 154.0
# 29.98
# 37.29
# 19.98
# 65.1
# 33.75
# 71128.1
# 34.0
# 142.0
# 128.33
